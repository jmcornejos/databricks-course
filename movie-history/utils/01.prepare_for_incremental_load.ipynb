# %%
# %sql
DROP DATABASE IF EXISTS moviehistory.movie_silver CASCADE

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS moviehistory.movie_silver

# %%
# %sql
DROP DATABASE IF EXISTS moviehistory.movie_gold CASCADE;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS moviehistory.movie_gold
